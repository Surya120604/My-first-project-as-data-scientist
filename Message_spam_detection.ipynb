# %% [markdown]
# <a href="https://colab.research.google.com/github/Surya120604/My-first-project-in-data-science/blob/main/Message_spam_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir .p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘.p’: File exists
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !kaggle datasets download -d uciml/sms-spam-collection-dataset
# Out:
# ...
# sms-spam-collection-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
data=pd.read_csv('/content/sms-spam-collection-dataset.zip',encoding='latin-2')

# %%
data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_15.groupby('Category').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_16.groupby('Message').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.isna().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
data.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1,inplace=True)

# %%
data.columns=['Category','Message']

# %%
data.head(100)
# Out:
#    Category                                            Message
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ..      ...                                                ...
# 95     spam  Your free ringtone is waiting to be collected....
# 96      ham                  Watching telugu movie..wat abt u?
# 97      ham  i see. When we finish we have loads of loans t...
# 98      ham  Hi. Wk been ok - on hols now! Yes on for a bit...
# 99      ham  Please don't text me anymore. I have nothing e...
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data['Category'].value_counts()
# Out:
# ham     4825
# spam     747
# Name: Category, dtype: int64

# %%
data['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['Spam']=data['Category'].apply(lambda x:'SPAM' if x=='spam' else "HAM")

# %%
data.columns
# Out:
# Index(['Category', 'Message', 'Spam'], dtype='object')

# %%
data.head(100)
# Out:
#    Category                                            Message  Spam
# 0       ham  Go until jurong point, crazy.. Available only ...   HAM
# 1       ham                      Ok lar... Joking wif u oni...   HAM
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...  SPAM
# 3       ham  U dun say so early hor... U c already then say...   HAM
# 4       ham  Nah I don't think he goes to usf, he lives aro...   HAM
# ..      ...                                                ...   ...
# 95     spam  Your free ringtone is waiting to be collected....  SPAM
# 96      ham                  Watching telugu movie..wat abt u?   HAM
# 97      ham  i see. When we finish we have loads of loans t...   HAM
# 98      ham  Hi. Wk been ok - on hols now! Yes on for a bit...   HAM
# 99      ham  Please don't text me anymore. I have nothing e...   HAM
#
# [100 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...

# %%
x=np.array(data["Message"])
y=np.array(data["Spam"])
cv=CountVectorizer()
X=cv.fit_transform(x)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=42)

clf=MultinomialNB()
clf.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
sample=input("ENTER THE MESSAGE : ")
data=cv.transform([sample]).toarray()
print(clf.predict(data))
# Out:
# ENTER THE MESSAGE :  hi this is kumar
# ['HAM']

# %%
clf.score(X_test,y_test)
# Out:
# 0.9784688995215312
